# %%
import torch
def print_model_size(model):
    total_params = sum(p.numel() for p in model.parameters())
    total_params_mb = total_params * 4 / (1024 ** 2)  # 4 bytes per parameter for float32
    print(f"Total Parameters: {total_params}")
    print(f"Approximate Model Size: {total_params_mb:.2f} MB")

model = torch.load("best.pt")
print_model_size(model)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 8
#       5     print(f"Total Parameters: {total_params}")
#       6     print(f"Approximate Model Size: {total_params_mb:.2f} MB")
# ----> 8 model = torch.load("best.pt")
#       9 print_model_size(model)
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:1025, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1023             except RuntimeError as e:
#    1024                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1025         return _load(opened_zipfile,
#    1026                      map_location,
#    1027                      pickle_module,
#    1028                      overall_storage=overall_storage,
#    1029                      **pickle_load_args)
#    1030 if mmap:
#    1031     f_name = "" if not isinstance(f, str) else f"{f}, "
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:1446, in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1444 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1445 unpickler.persistent_load = persistent_load
# -> 1446 result = unpickler.load()
#    1448 torch._utils._validate_loaded_sparse_tensors()
#    1449 torch._C._log_api_usage_metadata(
#    1450     "torch.load.metadata", {"serialization_id": zip_file.serialization_id()}
#    1451 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/serialization.py:1439, in _load.<locals>.UnpicklerWrapper.find_class(self, mod_name, name)
#    1437         pass
#    1438 mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1439 return super().find_class(mod_name, name)
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/__init__.py:11
#       8 if not os.environ.get("OMP_NUM_THREADS"):
#       9     os.environ["OMP_NUM_THREADS"] = "1"  # default for reduced CPU utilization during training
# ---> 11 from ultralytics.models import NAS, RTDETR, SAM, YOLO, FastSAM, YOLOWorld
#      12 from ultralytics.utils import ASSETS, SETTINGS
#      13 from ultralytics.utils.checks import check_yolo as checks
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/models/__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .fastsam import FastSAM
#       4 from .nas import NAS
#       5 from .rtdetr import RTDETR
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/models/fastsam/__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .model import FastSAM
#       4 from .predict import FastSAMPredictor
#       5 from .val import FastSAMValidator
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/models/fastsam/model.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 from pathlib import Path
# ----> 5 from ultralytics.engine.model import Model
#       7 from .predict import FastSAMPredictor
#       8 from .val import FastSAMValidator
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/engine/model.py:11
#       8 import torch
#       9 from PIL import Image
# ---> 11 from ultralytics.cfg import TASK2DATA, get_cfg, get_save_dir
#      12 from ultralytics.engine.results import Results
#      13 from ultralytics.hub import HUB_WEB_ROOT, HUBTrainingSession
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/cfg/__init__.py:12
#       8 from typing import Dict, List, Union
#      10 import cv2
# ---> 12 from ultralytics.utils import (
#      13     ASSETS,
#      14     ASSETS_URL,
#      15     DEFAULT_CFG,
#      16     DEFAULT_CFG_DICT,
#      17     DEFAULT_CFG_PATH,
#      18     DEFAULT_SOL_DICT,
#      19     IS_VSCODE,
#      20     LOGGER,
#      21     RANK,
#      22     ROOT,
#      23     RUNS_DIR,
#      24     SETTINGS,
#      25     SETTINGS_FILE,
#      26     TESTS_RUNNING,
#      27     IterableSimpleNamespace,
#      28     __version__,
#      29     checks,
#      30     colorstr,
#      31     deprecation_warn,
#      32     vscode_msg,
#      33     yaml_load,
#      34     yaml_print,
#      35 )
#      37 # Define valid solutions
#      38 SOLUTION_MAP = {
#      39     "count": ("ObjectCounter", "count"),
#      40     "heatmap": ("Heatmap", "generate_heatmap"),
#    (...)
#      45     "help": None,
#      46 }
#
# File ~/Library/Python/3.9/lib/python/site-packages/ultralytics/utils/__init__.py:23
#      20 from typing import Union
#      22 import cv2
# ---> 23 import matplotlib.pyplot as plt
#      24 import numpy as np
#      25 import torch
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/__init__.py:967
#     961     return config
#     964 # When constructing the global instances, we need to perform certain updates
#     965 # by explicitly calling the superclass (dict.update, dict.items) to avoid
#     966 # triggering resolution of _auto_backend_sentinel.
# --> 967 rcParamsDefault = _rc_params_in_file(
#     968     cbook._get_data_path("matplotlibrc"),
#     969     # Strip leading comment.
#     970     transform=lambda line: line[1:] if line.startswith("#") else line,
#     971     fail_on_error=True)
#     972 dict.update(rcParamsDefault, rcsetup._hardcoded_defaults)
#     973 # Normally, the default matplotlibrc file contains *no* entry for backend (the
#     974 # corresponding line starts with ##, not #; we fill on _auto_backend_sentinel
#     975 # in that case.  However, packagers can set a different default backend
#     976 # (resulting in a normal `#backend: foo` line) in which case we should *not*
#     977 # fill in _auto_backend_sentinel.
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/__init__.py:901, in _rc_params_in_file(fname, transform, fail_on_error)
#     899 if key in rcsetup._validators:
#     900     if fail_on_error:
# --> 901         config[key] = val  # try to convert to proper type or raise
#     902     else:
#     903         try:
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/__init__.py:736, in RcParams.__setitem__(self, key, val)
#     734             return
#     735 try:
# --> 736     cval = self.validate[key](val)
#     737 except ValueError as ve:
#     738     raise ValueError(f"Key {key}: {ve}") from None
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/rcsetup.py:342, in validate_color(s)
#     339         if is_color_like(stmp):
#     340             return stmp
# --> 342 if is_color_like(s):
#     343     return s
#     345 # If it is still valid, it must be a tuple (as a string from matplotlibrc).
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/colors.py:227, in is_color_like(c)
#     225     return True
#     226 try:
# --> 227     to_rgba(c)
#     228 except (TypeError, ValueError):
#     229     return False
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/colors.py:314, in to_rgba(c, alpha)
#     312     rgba = None
#     313 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 314     rgba = _to_rgba_no_colorcycle(c, alpha)
#     315     try:
#     316         _colors_full_map.cache[c, alpha] = rgba
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/colors.py:336, in _to_rgba_no_colorcycle(c, alpha)
#     334     raise ValueError("'alpha' must be between 0 and 1, inclusive")
#     335 orig_c = c
# --> 336 if c is np.ma.masked:
#     337     return (0., 0., 0., 0.)
#     338 if isinstance(c, str):
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/__init__.py:343, in __getattr__(attr)
#     336 def __dir__():
#     337     public_symbols = globals().keys() | {'testing'}
#     338     public_symbols -= {
#     339         "core", "matrixlib",
#     340         # These were moved in 1.25 and may be deprecated eventually:
#     341         "ModuleDeprecationWarning", "VisibleDeprecationWarning",
#     342         "ComplexWarning", "TooHardError", "AxisError"
# --> 343     }
#     344     return list(public_symbols)
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/ma/__init__.py:42
#       1 """
#       2 =============
#       3 Masked Arrays
#    (...)
#      40
#      41 """
# ---> 42 from . import core
#      43 from .core import *
#      45 from . import extras
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/ma/core.py:37
#      35 from numpy import ndarray, amax, amin, iscomplexobj, bool_, _NoValue
#      36 from numpy import array as narray
# ---> 37 from numpy.lib.function_base import angle
#      38 from numpy.compat import (
#      39     getargspec, formatargspec, long, unicode, bytes
#      40     )
#      41 from numpy import expand_dims
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/lib/function_base.py:25
#      23 from numpy.core import overrides
#      24 from numpy.core.function_base import add_newdoc
# ---> 25 from numpy.lib.twodim_base import diag
#      26 from numpy.core.multiarray import (
#      27     _place, add_docstring, bincount, normalize_axis_index, _monotonicity,
#      28     interp as compiled_interp, interp_complex as compiled_interp_complex
#      29     )
#      30 from numpy.core.umath import _add_newdoc_ufunc as add_newdoc_ufunc
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/lib/twodim_base.py:15
#      13 from numpy.core import overrides
#      14 from numpy.core import iinfo
# ---> 15 from numpy.lib.stride_tricks import broadcast_to
#      18 __all__ = [
#      19     'diag', 'diagflat', 'eye', 'fliplr', 'flipud', 'tri', 'triu',
#      20     'tril', 'vander', 'histogram2d', 'mask_indices', 'tril_indices',
#      21     'tril_indices_from', 'triu_indices', 'triu_indices_from', ]
#      24 array_function_dispatch = functools.partial(
#      25     overrides.array_function_dispatch, module='numpy')
#
# ImportError: cannot import name 'broadcast_to' from 'numpy.lib.stride_tricks' (/Users/jinseopsong/Library/Python/3.9/lib/python/site-packages/numpy/lib/stride_tricks.py)
